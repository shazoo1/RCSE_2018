# %% [markdown]
# Some links:
# - http://www.saedsayad.com/artificial_neural_network_bkp.htm

# %% [markdown]
# ## Single layer network with binary output. Hebbian learning rule.

# %% [markdown]
# ##  Single layer network
#
# Single layer network - also known as Perceptron - is a feed forward network based on a threshold transfer function.
#
# SLP is the simpliest type of artificial neural networks and can only classify linearly separable cases with a binary target (1,0)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Because SLP is a linear classifier and if the cases are not linearly separable the learning process will never reach a point where all the cases are classified properly.
#
# The most famous example of the inability of perceptron to solve problems with linearly non-separable cases is the XOR problem.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hebbian learning rule

# %% [markdown]
# - Introduced by Donald Hebb in his 1949 book "The organization of Behavior".
# - Describes a basic mechanism for synaptic plasticity
#
# That rule set up a principe to learn a specific training pattern to change weights correspondingly.
#
# ** For better undestanding write all by yourself**
#
# The matrix form of hebbian learning rule is quide descriptive.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
